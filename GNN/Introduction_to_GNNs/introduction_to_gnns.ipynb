# %% [markdown]
# [Intro to graph neural networks (ML Tech Talks)](https://www.youtube.com/watch?v=8owQBFAHw7E)

# %%
# !pip install numpy  # ==1.18.5
# !pip install tensorflow==2.3.0
# !pip install spektral==0.6.2

import numpy as np

np.float = float  # module 'numpy' has no attribute 'float'
np.int = int  # module 'numpy' has no attribute 'int'
np.bool = bool  # module 'numpy' has no attribute 'bool'
np.object = object  # module 'numpy' has no attribute 'object'

import tensorflow as tf
import spektral
# Out:
#   ▄█▀ █ █ ▀█▄    ▄█▀ █ █ ▀█▄    ▄█▀ █ █ ▀█▄    ▄█▀ █ █ ▀█▄    ▄█▀ █ █ ▀█▄    ▄█▀ █ █ ▀█▄
#  ███  ███  ███  ███  ███  ███  ███  ███  ███  ███  ███  ███  ███  ███  ███  ███  ███  ███
#  █████████████  █████████████  █████████████  █████████████  █████████████  █████████████
#   ▀██▄   ▄██▀    ▀██▄   ▄██▀    ▀██▄   ▄██▀    ▀██▄   ▄██▀    ▀██▄   ▄██▀    ▀██▄   ▄██▀
#
#
#   ▄█▀ █ █ ▀█▄    ▄█▀ █ █ ▀█▄    ▄█▀ █ █ ▀█▄    ▄█▀ █ █ ▀█▄    ▄█▀ █ █ ▀█▄    ▄█▀ █ █ ▀█▄
#  ███  ███  ███  ███  ███  ███  ███  ███  ███  ███  ███  ███  ███  ███  ███  ███  ███  ███
#  █████████████  █████████████  █████████████  █████████████  █████████████  █████████████
#   ▀██▄   ▄██▀    ▀██▄   ▄██▀    ▀██▄   ▄██▀    ▀██▄   ▄██▀    ▀██▄   ▄██▀    ▀██▄   ▄██▀
#
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (1.24.3)
# DEPRECATION: distro-info 1.1build1 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of distro-info or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: gpg 1.16.0-unknown has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of gpg or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: python-debian 0.1.43ubuntu1 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of python-debian or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
#  █   █  █   █  █   █  █   █  █   █  █   █
#   ■ ■    ■ ■    ■ ■    ■ ■    ■ ■    ■ ■
#   =■=    =■=    =■=    =■=    =■=    =■=
#
#  █=@=█  █=@=█  █=@=█  █=@=█  █=@=█  █=@=█
#   ■ ■    ■ ■    ■ ■    ■ ■    ■ ■    ■ ■
#   =■=    =■=    =■=    =■=    =■=    =■=
#
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.3.0 (from versions: 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.11.1, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.0.post1)
# ERROR: No matching distribution found for tensorflow==2.3.0
#
#  ▀■▄ ▀■▄ ▀■▄ ▀■▄ ▀■▄ ▀■▄
#   ▀■▄ ▀■▄ ▀■▄ ▀■▄ ▀■▄ ▀■▄
#
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spektral==0.6.2 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (0.6.2)
# Requirement already satisfied: tensorflow>=2.1.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from spektral==0.6.2) (2.13.0)
# Requirement already satisfied: networkx in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from spektral==0.6.2) (3.1)
# Requirement already satisfied: pandas in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from spektral==0.6.2) (2.1.1)
# Requirement already satisfied: lxml in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from spektral==0.6.2) (4.9.3)
# Requirement already satisfied: joblib in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from spektral==0.6.2) (1.3.2)
# Requirement already satisfied: numpy in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from spektral==0.6.2) (1.24.3)
# Requirement already satisfied: scipy in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from spektral==0.6.2) (1.11.3)
# Requirement already satisfied: requests in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from spektral==0.6.2) (2.31.0)
# Requirement already satisfied: scikit-learn in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from spektral==0.6.2) (1.0.2)
# Requirement already satisfied: absl-py>=1.0.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (1.58.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (3.9.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (2.13.1)
# Requirement already satisfied: libclang>=13.0.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (3.3.0)
# Requirement already satisfied: packaging in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (4.21.12)
# Requirement already satisfied: setuptools in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (1.16.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral==0.6.2) (0.34.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from pandas->spektral==0.6.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from pandas->spektral==0.6.2) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from pandas->spektral==0.6.2) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from requests->spektral==0.6.2) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from requests->spektral==0.6.2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from requests->spektral==0.6.2) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from requests->spektral==0.6.2) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from scikit-learn->spektral==0.6.2) (3.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow>=2.1.0->spektral==0.6.2) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral==0.6.2) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral==0.6.2) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral==0.6.2) (3.4.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral==0.6.2) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral==0.6.2) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral==0.6.2) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral==0.6.2) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral==0.6.2) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral==0.6.2) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral==0.6.2) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral==0.6.2) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral==0.6.2) (3.2.2)
# DEPRECATION: distro-info 1.1build1 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of distro-info or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: gpg 1.16.0-unknown has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of gpg or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: python-debian 0.1.43ubuntu1 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of python-debian or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# 2023-12-18 14:10:14.186593: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-18 14:10:14.188317: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-18 14:10:14.216848: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-18 14:10:14.217462: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-18 14:10:14.760641: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# load the cora dataset, preprocess and give access to these pieces of information
adj, features, labels, train_mask, val_mask, test_mask = spektral.datasets.citation.load_data(dataset_name='cora')

features = features.todense()  # comes as sparse information, so casting to a denser representation
adj = adj.todense() + np.eye(adj.shape[0])  # adjacency matrix comes withou self-edges, adding identity matrix to it
features = features.astype('float32')
adj = adj.astype('float32')

print(features.shape)
print(adj.shape)
print(labels.shape)

print(np.sum(train_mask))
print(np.sum(val_mask))
print(np.sum(test_mask))
# Out:
# Loading cora dataset
# Pre-processing node features
# (2708, 1433)
# (2708, 2708)
# (2708, 7)
# 140
# 500
# 1000

# %%
def masked_softmax_cross_entropy(logits, labels, mask):
    loss = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels)
    mask = tf.cast(mask, dtype=tf.float32)
    mask /= tf.reduce_mean(mask)
    loss *= mask
    return tf.reduce_mean(loss)

def masked_accuracy(logits, labels, mask):
    correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
    accuracy_all = tf.cast(correct_prediction, tf.float32)
    mask = tf.cast(mask, dtype=tf.float32)
    mask /= tf.reduce_mean(mask)
    accuracy_all *= mask
    return tf.reduce_mean(accuracy_all)

# %%
def gnn(fts, adj, transform, activation):
    seq_fts = transform(fts)
    ret_fts = tf.matmul(adj, seq_fts)
    return activation(ret_fts)

# %%
def train_cora(fts, adj, gnn_fn, units, epochs, lr):
    lyr_1 = tf.keras.layers.Dense(units)  # computes the hidden layer
    lyr_2 = tf.keras.layers.Dense(7)  # computas the classification for each node -> 7 outputs for 7 classes

    def cora_gnn(fts, adj):
        hidden = gnn_fn(fts, adj, lyr_1, tf.nn.relu)  # computes the hidden features in every node
        logits = gnn_fn(hidden, adj, lyr_2, tf.identity)  # neural networks predictions
        return logits
    
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)  #standard optimizer

    best_accuracy = 0.0
    for ep in range(epochs + 1):
        with tf.GradientTape() as t:  # tf.GradientTape() to record the gradients
            logits = cora_gnn(fts, adj)  # compute predictions
            loss = masked_softmax_cross_entropy(logits, labels, train_mask)  # compute the loss (training set)

        variables = t.watched_variables()
        grads = t.gradient(loss, variables)
        optimizer.apply_gradients(zip(grads, variables))

        logits = cora_gnn(fts, adj)
        val_accuracy = masked_accuracy(logits, labels, val_mask)
        test_accuracy = masked_accuracy(logits, labels, test_mask)

        if val_accuracy > best_accuracy:
            best_accuracy = val_accuracy
            print('Epoch', ep, '| Training loss:', loss.numpy(), '| Val accuracy:',
                val_accuracy.numpy(), '| Test accuracy:', test_accuracy.numpy())

# %%
train_cora(features, adj, gnn, 32, 200, 0.01)  # standard parameters
# passing raw adjacency matrix which means we'll be multiplying our features with just a 0 1 matrix
# therefore we're implementing sumpooling. expected problems with the scale of the features
# as a result it might not give us the best result possible
# Out:
# Epoch 0 | Training loss: 1.993462 | Val accuracy: 0.116 | Test accuracy: 0.151
# Epoch 1 | Training loss: 1.808962 | Val accuracy: 0.17599998 | Test accuracy: 0.171
# Epoch 2 | Training loss: 2.025656 | Val accuracy: 0.328 | Test accuracy: 0.33599997
# Epoch 3 | Training loss: 1.5937511 | Val accuracy: 0.616 | Test accuracy: 0.613
# Epoch 8 | Training loss: 1.0398486 | Val accuracy: 0.662 | Test accuracy: 0.654
# Epoch 9 | Training loss: 0.95276517 | Val accuracy: 0.688 | Test accuracy: 0.69200003
# Epoch 14 | Training loss: 0.6364694 | Val accuracy: 0.696 | Test accuracy: 0.709
# Epoch 18 | Training loss: 0.4498574 | Val accuracy: 0.72 | Test accuracy: 0.739
# Epoch 19 | Training loss: 0.40629724 | Val accuracy: 0.74399996 | Test accuracy: 0.75399995
# Epoch 25 | Training loss: 0.24033621 | Val accuracy: 0.746 | Test accuracy: 0.76800007
# Epoch 26 | Training loss: 0.22193703 | Val accuracy: 0.74799997 | Test accuracy: 0.767

# %%
train_cora(features, tf.eye(adj.shape[0]), gnn, 32, 200, 0.01)  # replacing the adjacency matrix with the identity matrix
# it will render the operation of multiplying with the adjacency matrix not changing anything
# so we just have basically a pointwise classifier in each of our nodes
# so a standard MLP Model that's shared across the vertices
# Out:
# Epoch 0 | Training loss: 1.9457034 | Val accuracy: 0.18 | Test accuracy: 0.173
# Epoch 1 | Training loss: 1.9319072 | Val accuracy: 0.344 | Test accuracy: 0.344
# Epoch 2 | Training loss: 1.9124532 | Val accuracy: 0.41199997 | Test accuracy: 0.43899995
# Epoch 3 | Training loss: 1.887785 | Val accuracy: 0.41399997 | Test accuracy: 0.45499995
# Epoch 4 | Training loss: 1.8597511 | Val accuracy: 0.44599998 | Test accuracy: 0.46199998
# Epoch 5 | Training loss: 1.829275 | Val accuracy: 0.44799998 | Test accuracy: 0.47799993
# Epoch 7 | Training loss: 1.7591162 | Val accuracy: 0.45999998 | Test accuracy: 0.48699996
# Epoch 8 | Training loss: 1.7194053 | Val accuracy: 0.466 | Test accuracy: 0.49599993
# Epoch 26 | Training loss: 0.7053366 | Val accuracy: 0.468 | Test accuracy: 0.48899996
# Epoch 27 | Training loss: 0.6496189 | Val accuracy: 0.474 | Test accuracy: 0.49799994
# Epoch 28 | Training loss: 0.596165 | Val accuracy: 0.476 | Test accuracy: 0.50899994
# Epoch 29 | Training loss: 0.54521954 | Val accuracy: 0.48 | Test accuracy: 0.50899994
# Epoch 30 | Training loss: 0.49699986 | Val accuracy: 0.48599997 | Test accuracy: 0.51299995
# Epoch 31 | Training loss: 0.4516552 | Val accuracy: 0.48799998 | Test accuracy: 0.5109999
# Epoch 32 | Training loss: 0.40931457 | Val accuracy: 0.48999998 | Test accuracy: 0.51199996
# Epoch 33 | Training loss: 0.37004876 | Val accuracy: 0.496 | Test accuracy: 0.5149999
# Epoch 35 | Training loss: 0.300674 | Val accuracy: 0.49999994 | Test accuracy: 0.51699996
# Epoch 39 | Training loss: 0.1958768 | Val accuracy: 0.50200003 | Test accuracy: 0.50999993

# %%
# meanpooling
deg = tf.reduce_sum(adj, axis=-1)  # degree matrix - the degree of each node
train_cora(features, adj / deg, gnn, 32, 200, 0.01)  # adj / deg = covalent to multiplying it with the inverse of the degree matrix
# this will give us a normalized propagation rule - which should hopefully deal with any exploding signal
# Out:
# Epoch 0 | Training loss: 1.9453741 | Val accuracy: 0.21 | Test accuracy: 0.21599999
# Epoch 1 | Training loss: 1.932291 | Val accuracy: 0.29 | Test accuracy: 0.296
# Epoch 5 | Training loss: 1.857199 | Val accuracy: 0.292 | Test accuracy: 0.295
# Epoch 6 | Training loss: 1.8349357 | Val accuracy: 0.30199996 | Test accuracy: 0.306
# Epoch 7 | Training loss: 1.8112036 | Val accuracy: 0.31799996 | Test accuracy: 0.32299998
# Epoch 8 | Training loss: 1.7855774 | Val accuracy: 0.33799997 | Test accuracy: 0.342
# Epoch 9 | Training loss: 1.7578923 | Val accuracy: 0.34999996 | Test accuracy: 0.361
# Epoch 10 | Training loss: 1.7279224 | Val accuracy: 0.36399996 | Test accuracy: 0.37999997
# Epoch 11 | Training loss: 1.6961602 | Val accuracy: 0.38799998 | Test accuracy: 0.40999997
# Epoch 12 | Training loss: 1.6629497 | Val accuracy: 0.42999998 | Test accuracy: 0.44199997
# Epoch 13 | Training loss: 1.6279391 | Val accuracy: 0.472 | Test accuracy: 0.48999998
# Epoch 14 | Training loss: 1.59126 | Val accuracy: 0.52599996 | Test accuracy: 0.525
# Epoch 15 | Training loss: 1.5530323 | Val accuracy: 0.55799997 | Test accuracy: 0.56499994
# Epoch 16 | Training loss: 1.5132507 | Val accuracy: 0.58199996 | Test accuracy: 0.59999996
# Epoch 17 | Training loss: 1.4720314 | Val accuracy: 0.614 | Test accuracy: 0.63
# Epoch 18 | Training loss: 1.4297642 | Val accuracy: 0.63199997 | Test accuracy: 0.648
# Epoch 19 | Training loss: 1.3862791 | Val accuracy: 0.64599997 | Test accuracy: 0.66899997
# Epoch 20 | Training loss: 1.341664 | Val accuracy: 0.668 | Test accuracy: 0.68999994
# Epoch 21 | Training loss: 1.2961159 | Val accuracy: 0.698 | Test accuracy: 0.706
# Epoch 22 | Training loss: 1.2499602 | Val accuracy: 0.72 | Test accuracy: 0.72499996
# Epoch 23 | Training loss: 1.2033749 | Val accuracy: 0.7279999 | Test accuracy: 0.73999995
# Epoch 24 | Training loss: 1.156433 | Val accuracy: 0.73599994 | Test accuracy: 0.755
# Epoch 25 | Training loss: 1.1093591 | Val accuracy: 0.75200003 | Test accuracy: 0.763
# Epoch 26 | Training loss: 1.0623751 | Val accuracy: 0.75399995 | Test accuracy: 0.7720001
# Epoch 27 | Training loss: 1.0157 | Val accuracy: 0.766 | Test accuracy: 0.779
# Epoch 29 | Training loss: 0.923928 | Val accuracy: 0.774 | Test accuracy: 0.79399997
# Epoch 30 | Training loss: 0.8791484 | Val accuracy: 0.77599996 | Test accuracy: 0.79800004
# Epoch 31 | Training loss: 0.8353212 | Val accuracy: 0.782 | Test accuracy: 0.8000001
# Epoch 32 | Training loss: 0.79261947 | Val accuracy: 0.784 | Test accuracy: 0.8030001
# Epoch 34 | Training loss: 0.7111477 | Val accuracy: 0.7879999 | Test accuracy: 0.807
# Epoch 35 | Training loss: 0.67261255 | Val accuracy: 0.78999996 | Test accuracy: 0.811
# Epoch 36 | Training loss: 0.63560337 | Val accuracy: 0.79199994 | Test accuracy: 0.811

# %%
# specific version of the normalization that Thomas Kipf has proposed in the
# Graph Convolutional Network Model 1/sqrt(deg) and then multiply that on the both sides of the adjacency matrix
# so you can get a normalized adjacency matrix
norm_deg = tf.linalg.diag(1.0 / tf.sqrt(deg))
norm_adj = tf.matmul(norm_deg, tf.matmul(adj, norm_deg)) # equivalent to D^{-1/2} and then multiplying the adjacency matris on both sides
train_cora(features, norm_adj, gnn, 32, 200, 0.01)
# Out:
