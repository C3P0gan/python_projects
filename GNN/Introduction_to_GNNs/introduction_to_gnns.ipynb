# %%
# !pip install numpy  # 1.18.5
# !pip install tensorflow  # 2.3.0
# !pip install spektral  # 0.6.2

import numpy as np
import tensorflow as tf
import spektral
# Out:
#  ._________________________________.
#  |                                 |
#  |                 _               |
#  |                //\              |
#  |          //-- //  \  ========,  |
#  |         //   //    \        /   |
#  |        //   //      \      /    |
#  |  __________  ___  __  _________ |
#  |       /     \        //  //     |
#  |      /       \      //  //      |
#  |     /__________________//       |
#  |                \  //            |
#  |                 \//             |
#  |                  "              |
#  |                                 |
#  '---------------------------------'
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (1.24.3)
# DEPRECATION: distro-info 1.1build1 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of distro-info or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: gpg 1.16.0-unknown has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of gpg or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: python-debian 0.1.43ubuntu1 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of python-debian or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
#
#    ▄███████▄                  ▄██████▄      ▄██████▄      ▄██████▄      ▄██████▄      ▄██████▄
#  ▄█████████▀▀               ▄█▀████▀███▄  ▄██████████▄  ▄██████████▄  ▄██████████▄  ▄███▀████▀█▄
#  ███████▀      ▄▄  ▄▄  ▄▄   █▄▄███▄▄████  ███ ████ ███  ███ ████ ███  ███ ████ ███  ████▄▄███▄▄█
#  ███████▄      ▀▀  ▀▀  ▀▀   ████████████  ████████████  ████████████  ████████████  ████████████
#  ▀█████████▄▄               ██▀██▀▀██▀██  ██▀██▀▀██▀██  ██▀██▀▀██▀██  ██▀██▀▀██▀██  ██▀██▀▀██▀██
#    ▀███████▀                ▀   ▀  ▀   ▀  ▀   ▀  ▀   ▀  ▀   ▀  ▀   ▀  ▀   ▀  ▀   ▀  ▀   ▀  ▀   ▀
#
#    ▄███████▄                  ▄██████▄      ▄██████▄      ▄██████▄      ▄██████▄      ▄██████▄
#  ▄█████████▀▀               ▄█▀████▀███▄  ▄██ ████ ██▄  ▄██ ████ ██▄  ▄██ ████ ██▄  ▄███▀████▀█▄
#  ███████▀      ▄▄  ▄▄  ▄▄   █▄▄███▄▄████  ████████████  ████████████  ████████████  ████▄▄███▄▄█
#  ███████▄      ▀▀  ▀▀  ▀▀   ████████████  ████████████  ████████████  ████████████  ████████████
#  ▀█████████▄▄               ██▀██▀▀██▀██  ██▀██▀▀██▀██  ██▀██▀▀██▀██  ██▀██▀▀██▀██  ██▀██▀▀██▀██
#    ▀███████▀                ▀   ▀  ▀   ▀  ▀   ▀  ▀   ▀  ▀   ▀  ▀   ▀  ▀   ▀  ▀   ▀  ▀   ▀  ▀   ▀
#
#
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (1.58.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (2.13.1)
# Requirement already satisfied: libclang>=13.0.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (4.21.12)
# Requirement already satisfied: setuptools in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (1.26.18)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (3.2.2)
# DEPRECATION: distro-info 1.1build1 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of distro-info or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: gpg 1.16.0-unknown has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of gpg or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: python-debian 0.1.43ubuntu1 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of python-debian or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
#  ▬▬▬▬▬ ▬▬▬▬▬ ▬▬▬▬▬ ▬▬▬▬▬ ▬▬▬▬▬ ▬▬▬▬▬
#  ▬▬▬▬▬ ▬▬▬▬▬ ▬▬▬▬▬ ▬▬▬▬▬ ▬▬▬▬▬ ▬▬▬▬▬
#
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spektral in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (0.6.2)
# Requirement already satisfied: tensorflow>=2.1.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from spektral) (2.13.0)
# Requirement already satisfied: networkx in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from spektral) (3.1)
# Requirement already satisfied: pandas in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from spektral) (2.1.1)
# Requirement already satisfied: lxml in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from spektral) (4.9.3)
# Requirement already satisfied: joblib in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from spektral) (1.3.2)
# Requirement already satisfied: numpy in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from spektral) (1.24.3)
# Requirement already satisfied: scipy in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from spektral) (1.11.3)
# Requirement already satisfied: requests in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from spektral) (2.31.0)
# Requirement already satisfied: scikit-learn in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from spektral) (1.0.2)
# Requirement already satisfied: absl-py>=1.0.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (1.58.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (3.9.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (2.13.1)
# Requirement already satisfied: libclang>=13.0.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (3.3.0)
# Requirement already satisfied: packaging in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (4.21.12)
# Requirement already satisfied: setuptools in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (1.16.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorflow>=2.1.0->spektral) (0.34.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from pandas->spektral) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from pandas->spektral) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from pandas->spektral) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from requests->spektral) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from requests->spektral) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from requests->spektral) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from requests->spektral) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from scikit-learn->spektral) (3.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow>=2.1.0->spektral) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral) (3.4.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/cristoffer_pogan/.local/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow>=2.1.0->spektral) (3.2.2)
# DEPRECATION: distro-info 1.1build1 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of distro-info or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: gpg 1.16.0-unknown has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of gpg or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: python-debian 0.1.43ubuntu1 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of python-debian or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# 2023-12-18 13:02:50.800238: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-18 13:02:50.801651: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-18 13:02:50.830553: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-18 13:02:50.831915: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-18 13:02:51.515913: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/cristoffer_pogan/Documents/dev/Python/GNN/Introduction_to_GNNs/introduction_to_gnns.ipynb Cell 1 line 7
#       <a href='vscode-notebook-cell:/home/cristoffer_pogan/Documents/dev/Python/GNN/Introduction_to_GNNs/introduction_to_gnns.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> import numpy as np
#       <a href='vscode-notebook-cell:/home/cristoffer_pogan/Documents/dev/Python/GNN/Introduction_to_GNNs/introduction_to_gnns.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> import tensorflow as tf
# ----> <a href='vscode-notebook-cell:/home/cristoffer_pogan/Documents/dev/Python/GNN/Introduction_to_GNNs/introduction_to_gnns.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> import spektral
#
# File ~/.local/lib/python3.10/site-packages/spektral/__init__.py:1
# ----> 1 from . import layers
#       2 from . import datasets
#       3 from . import utils
#
# File ~/.local/lib/python3.10/site-packages/spektral/layers/__init__.py:2
#       1 from .base import *
# ----> 2 from .convolutional import *
#       3 from .pooling import *
#       4 from . import ops
#
# File ~/.local/lib/python3.10/site-packages/spektral/layers/convolutional/__init__.py:1
# ----> 1 from .agnn_conv import AGNNConv
#       2 from .appnp import APPNP
#       3 from .arma_conv import ARMAConv
#
# File ~/.local/lib/python3.10/site-packages/spektral/layers/convolutional/agnn_conv.py:5
#       2 from tensorflow.keras import backend as K
#       4 from spektral.layers import ops
# ----> 5 from spektral.layers.convolutional.message_passing import MessagePassing
#       8 class AGNNConv(MessagePassing):
#       9     r"""
#      10     An Attention-based Graph Neural Network (AGNN) as presented by
#      11     [Thekumparampil et al. (2018)](https://arxiv.org/abs/1803.03735).
#    (...)
#      45     - `activation`: activation function to use;
#      46     """
#
# File ~/.local/lib/python3.10/site-packages/spektral/layers/convolutional/message_passing.py:7
#       4 from tensorflow.keras import backend as K
#       5 from tensorflow.keras.layers import Layer
# ----> 7 from spektral.utils.keras import is_layer_kwarg, is_keras_kwarg, deserialize_kwarg, serialize_kwarg
#       8 from spektral.layers.ops.scatter import deserialize_scatter
#      11 class MessagePassing(Layer):
#
# File ~/.local/lib/python3.10/site-packages/spektral/utils/__init__.py:1
# ----> 1 from .conversion import *
#       2 from .convolution import *
#       3 from .logging import *
#
# File ~/.local/lib/python3.10/site-packages/spektral/utils/conversion.py:4
#       1 import networkx as nx
#       2 import numpy as np
# ----> 4 from spektral.utils.misc import pad_jagged_array, add_eye_jagged, add_eye_batch, flatten_list
#       7 # Available conversions: Numpy <-> Networkx <-> SDF
#      10 def nx_to_adj(graphs):
#
# File ~/.local/lib/python3.10/site-packages/spektral/utils/misc.py:5
#       1 import numpy as np
#       2 from scipy import sparse as sp
# ----> 5 def pad_jagged_array(x, target_shape, dtype=np.float):
#       6     """
#       7     Given a jagged array of arbitrary dimensions, zero-pads all elements in the
#       8     array to match the provided `target_shape`.
#    (...)
#      18     :return: a zero-padded np.array of shape `(X.shape[0], ) + target_shape`
#      19     """
#      20     if isinstance(x, list):
#
# File ~/.local/lib/python3.10/site-packages/numpy/__init__.py:305, in __getattr__(attr)
#     300     warnings.warn(
#     301         f"In the future `np.{attr}` will be defined as the "
#     302         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     304 if attr in __former_attrs__:
# --> 305     raise AttributeError(__former_attrs__[attr])
#     307 # Importing Tester requires importing all of UnitTest which is not a
#     308 # cheap import Since it is mainly used in test suits, we lazy import it
#     309 # here to save on the order of 10 ms of import time for most users
#     310 #
#     311 # The previous way Tester was imported also had a side effect of adding
#     312 # the full `numpy.testing` namespace
#     313 if attr == 'testing':
#
# AttributeError: module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
# load the cora dataset, preprocess and give access to these pieces of information
adj, features, labels, train_mask, val_mask, test_mask = spektral.datasets.citation.load_data(dataset_name='cora')
# cora_dataset = spektral.datasets.citation.Citation(name='cora')

# graph = cora_dataset.graphs[0]
# adj = graph.a
# features = graph.x
# labels = graph.y
# train_mask = cora_dataset.mask_tr
# val_mask = cora_dataset.mask_va
# test_mask = cora_dataset.mask_te

# features = features.todense()  # comes as sparse information, so casting to a denser representation
# adj = adj.todense() + np.eye(adj.shape[0])  # adjacency matrix comes withou self-edges, adding identity matrix to it
# features = features.astype('float32')
# adj = adj.astype('float32')

print(features.shape)
print(adj.shape)
print(labels.shape)

print(np.sum(train_mask))
print(np.sum(val_mask))
print(np.sum(test_mask))
